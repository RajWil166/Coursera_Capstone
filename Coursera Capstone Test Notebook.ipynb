# %% [markdown]
# ## Notebook for Coursera Capstone Project

# %% [markdown]
# #### This Jupyter notebook would be uploaded to the Github repository

# %%
import pandas as pd
import numpy as np

# %%
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
